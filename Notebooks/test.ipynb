# %%
import kagglehub

handle = 'preetiv1/facial-dataset'
local_dataset_dir = '/Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/.claude/worktrees/objective-herschel-948fbf/data/processed'

# Create a new dataset
kagglehub.dataset_upload(handle, local_dataset_dir)

# You can then create a new version of this dataset and include version notes.
kagglehub.dataset_upload(handle, local_dataset_dir, version_notes='improved data')

# You can also specify a list of patterns for files/dirs to ignore.
# These patterns are combined with 'kagglehub.datasets.DEFAULT_IGNORE_PATTERNS'
# to determine which files and directories to exclude. 
# To ignore entire directories, include a trailing slash (/) in the pattern.
kagglehub.dataset_upload(handle, local_dataset_dir, ignore_patterns=["original/", "*.tmp"])
# Out:
# Uploading Dataset https://kaggle.com/datasets/preetiv1/facial-dataset ...
# More than 50 files detected, creating a zip archive...
# Starting upload for file /var/folders/l6/yqv6d1cx0qx2333dqjzt4m4r0000gn/T/tmp6ctz4t0m/archive.zip
# Uploading: 100%|██████████| 769M/769M [04:37<00:00, 2.77MB/s]
# Upload successful: /var/folders/l6/yqv6d1cx0qx2333dqjzt4m4r0000gn/T/tmp6ctz4t0m/archive.zip (734MB)
# Your dataset has been created.
# Files are being processed...
# See at: https://kaggle.com/datasets/preetiv1/facial-dataset
# Uploading Dataset https://kaggle.com/datasets/preetiv1/facial-dataset ...
# More than 50 files detected, creating a zip archive...
# Starting upload for file /var/folders/l6/yqv6d1cx0qx2333dqjzt4m4r0000gn/T/tmpbjpxpcts/archive.zip
# Uploading: 100%|██████████| 769M/769M [04:33<00:00, 2.81MB/s]
# Upload successful: /var/folders/l6/yqv6d1cx0qx2333dqjzt4m4r0000gn/T/tmpbjpxpcts/archive.zip (734MB)
# Your dataset version has been created.
# Files are being processed...
# See at: https://kaggle.com/datasets/preetiv1/facial-dataset
# Uploading Dataset https://kaggle.com/datasets/preetiv1/facial-dataset ...
# More than 50 files detected, creating a zip archive...
# Starting upload for file /var/folders/l6/yqv6d1cx0qx2333dqjzt4m4r0000gn/T/tmpz9606oxt/archive.zip
# Uploading: 100%|██████████| 769M/769M [04:31<00:00, 2.83MB/s]
# Upload successful: /var/folders/l6/yqv6d1cx0qx2333dqjzt4m4r0000gn/T/tmpz9606oxt/archive.zip (734MB)
# Your dataset version has been created.
# Files are being processed...
# See at: https://kaggle.com/datasets/preetiv1/facial-dataset

# %%
import kagglehub

handle = 'preetiv1/facial-dataset'
local_dataset_dir = '/Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details'

# Create a new dataset
kagglehub.dataset_upload(handle, local_dataset_dir)

# You can then create a new version of this dataset and include version notes.
kagglehub.dataset_upload(handle, local_dataset_dir, version_notes='improved data')

# You can also specify a list of patterns for files/dirs to ignore.
# These patterns are combined with 'kagglehub.datasets.DEFAULT_IGNORE_PATTERNS'
# to determine which files and directories to exclude. 
# To ignore entire directories, include a trailing slash (/) in the pattern.
kagglehub.dataset_upload(handle, local_dataset_dir, ignore_patterns=["original/", "*.tmp"])
# Out:
# Uploading Dataset https://kaggle.com/datasets/preetiv1/facial-dataset ...
# Starting upload for file /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/master_split.csv
# Uploading: 100%|██████████| 2.73M/2.73M [00:02<00:00, 938kB/s]
# Upload successful: /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/master_split.csv (3MB)
# Starting upload for file /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/class_weights.json
# Uploading: 100%|██████████| 162/162 [00:01<00:00, 144B/s]
# Upload successful: /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/class_weights.json (162B)
# Starting upload for file /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/yolov12n-face.pt
# Uploading: 100%|██████████| 5.50M/5.50M [00:02<00:00, 2.07MB/s]
# Upload successful: /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/yolov12n-face.pt (5MB)
# Your dataset version has been created.
# Files are being processed...
# See at: https://kaggle.com/datasets/preetiv1/facial-dataset
# Uploading Dataset https://kaggle.com/datasets/preetiv1/facial-dataset ...
# Starting upload for file /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/master_split.csv
# Uploading: 100%|██████████| 2.73M/2.73M [00:03<00:00, 853kB/s]
# Upload successful: /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/master_split.csv (3MB)
# Starting upload for file /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/class_weights.json
# Uploading: 100%|██████████| 162/162 [00:01<00:00, 141B/s]
# Upload successful: /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/class_weights.json (162B)
# Starting upload for file /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/yolov12n-face.pt
# Uploading: 100%|██████████| 5.50M/5.50M [00:06<00:00, 826kB/s]
# Upload successful: /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/yolov12n-face.pt (5MB)
# Your dataset version has been created.
# Files are being processed...
# See at: https://kaggle.com/datasets/preetiv1/facial-dataset
# Uploading Dataset https://kaggle.com/datasets/preetiv1/facial-dataset ...
# Starting upload for file /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/master_split.csv
# Uploading: 100%|██████████| 2.73M/2.73M [00:02<00:00, 1.14MB/s]
# Upload successful: /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/master_split.csv (3MB)
# Starting upload for file /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/class_weights.json
# Uploading: 100%|██████████| 162/162 [00:01<00:00, 146B/s]
# Upload successful: /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/class_weights.json (162B)
# Starting upload for file /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/yolov12n-face.pt
# Uploading: 100%|██████████| 5.50M/5.50M [00:04<00:00, 1.29MB/s]
# Upload successful: /Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/details/yolov12n-face.pt (5MB)
# Your dataset version has been created.
# Files are being processed...
# See at: https://kaggle.com/datasets/preetiv1/facial-dataset

# %%
from huggingface_hub import login, upload_folder
HF_TOKEN = "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"

# (optional) Login with your Hugging Face credentials
login(HF_TOKEN)

# Push your dataset files
upload_folder(folder_path="/Users/pv/Documents/STUDY/CODEprojects/project-1-emotion-aware-chatbot-team14/dataset/processed", repo_id="prenz1/Combined_facial_DS", repo_type="dataset")
